# %% [markdown]
# <a href="https://colab.research.google.com/github/YonDraco/learn-deep-learning/blob/main/mvtec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.8.1+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
# %cd /content/
# Out:
# /content

# %%
# !git clone https://github.com/xiahaifeng1995/FAVAE-anomaly-detection-localization-master.git
# Out:
# Cloning into 'FAVAE-anomaly-detection-localization-master'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (103/103), done.
# remote: Total 109 (delta 48), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (109/109), 923.02 KiB | 22.51 MiB/s, done.
# Resolving deltas: 100% (48/48), done.

# %%
link = "ftp://guest:GU%2E205dldo@ftp.softronics.ch/mvtec_anomaly_detection/bottle.tar.xz"
# !pip install wget
import wget
wget.download(link)
# Out:
# ...
# 'bottle.tar.xz'

# %%
# %cd /content/
# Out:
# /content

# %%
# !mkdir /content/data
# !mkdir /content/data/mvtec_anomaly_detection
# !mkdir /content/data/mvtec_anomaly_detection/mvtec_anomaly_detection

# %%
# %cd /content/data/mvtec_anomaly_detection/mvtec_anomaly_detection
# Out:
# /content/data/mvtec_anomaly_detection/mvtec_anomaly_detection

# %%
# !tar -xvf  /content/bottle.tar.xz
# Out:
# bottle/
# bottle/ground_truth/
# bottle/ground_truth/broken_large/
# bottle/ground_truth/broken_large/015_mask.png
# bottle/ground_truth/broken_large/016_mask.png
# bottle/ground_truth/broken_large/017_mask.png
# bottle/ground_truth/broken_large/018_mask.png
# bottle/ground_truth/broken_large/019_mask.png
# bottle/ground_truth/broken_large/000_mask.png
# bottle/ground_truth/broken_large/001_mask.png
# bottle/ground_truth/broken_large/002_mask.png
# bottle/ground_truth/broken_large/003_mask.png
# bottle/ground_truth/broken_large/004_mask.png
# bottle/ground_truth/broken_large/005_mask.png
# bottle/ground_truth/broken_large/006_mask.png
# bottle/ground_truth/broken_large/007_mask.png
# bottle/ground_truth/broken_large/008_mask.png
# bottle/ground_truth/broken_large/009_mask.png
# bottle/ground_truth/broken_large/010_mask.png
# bottle/ground_truth/broken_large/011_mask.png
# bottle/ground_truth/broken_large/012_mask.png
# bottle/ground_truth/broken_large/013_mask.png
# ...

# %%
# %cd /content/FAVAE-anomaly-detection-localization-master
# Out:
# /content/FAVAE-anomaly-detection-localization-master

# %%
# !python train.py --obj bottle --do_aug --data_path /content/data/mvtec_anomaly_detection/mvtec_anomaly_detection --batch_size 128
# Out:
# Augmenting 030.png ...
# Augmenting 069.png ...
# Augmenting 108.png ...
# Augmenting 091.png ...
# Augmenting 006.png ...
# Augmenting 167.png ...
# Augmenting 052.png ...
# Augmenting 162.png ...
# Augmenting 074.png ...
# Augmenting 020.png ...
# Augmenting 186.png ...
# Augmenting 201.png ...
# Augmenting 080.png ...
# Augmenting 033.png ...
# Augmenting 168.png ...
# Augmenting 160.png ...
# Augmenting 115.png ...
# Augmenting 097.png ...
# Augmenting 027.png ...
# Augmenting 198.png ...
# Augmenting 124.png ...
# Augmenting 010.png ...
# Augmenting 098.png ...
# Augmenting 025.png ...
# Augmenting 172.png ...
# Augmenting 145.png ...
# Augmenting 178.png ...
# Augmenting 001.png ...
# Augmenting 127.png ...
# Augmenting 113.png ...
# Augmenting 193.png ...
# Augmenting 188.png ...
# Augmenting 118.png ...
# Augmenting 156.png ...
# Augmenting 051.png ...
# Augmenting 132.png ...
# Augmenting 013.png ...
# Augmenting 063.png ...
# Augmenting 058.png ...
# Augmenting 158.png ...
# ...

# %%
import cv2

# %%
def loadImage(a):
  import cv2
  import matplotlib.pyplot as plt
  img = cv2.imread(a)
  plt.figure(figsize=(30,30))
  plt.imshow(img)

# %%
loadImage('/content/FAVAE-anomaly-detection-localization-master/mvtec/bottle/vgg_feature/seed_8719/100test-images.jpg')

# %%
# !python test.py --obj bottle --checkpoint_dir /content/FAVAE-anomaly-detection-localization-master/mvtec/bottle/vgg_feature/seed_8719/bottle_2021-04-16-2934_model.pt --data_path /content/data/mvtec_anomaly_detection/mvtec_anomaly_detection
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:258: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100% 6/6 [00:03<00:00,  1.94it/s]
# pixel ROCAUC: 0.950

# %%
loadImage('/content/FAVAE-anomaly-detection-localization-master/mvtec/bottle/vgg_feature/seed_None/seed_None/pictures_0.1636/bottle_0_png.png')

# %%
import os
f = os.listdir('/content/FAVAE-anomaly-detection-localization-master/mvtec/bottle/vgg_feature/seed_None/seed_None/pictures_0.1636')

# %%
for i in range(6):
  a='/content/FAVAE-anomaly-detection-localization-master/mvtec/bottle/vgg_feature/seed_None/seed_None/pictures_0.1636/'+f[0]
  loadImage(a)
