# %% [markdown]
# <a href="https://colab.research.google.com/github/YonDraco/learn-deep-learning/blob/main/2dimageto3dmodel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from IPython.display import Image, clear_output  # to display images

#clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.8.1+cu101 CPU

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/2DimageTo3dModel
# Out:
# /content/drive/MyDrive/2DimageTo3dModel

# %%
# !git clone https://github.com/NikolaZubic/2dimageto3dmodel.git
# Out:
# Cloning into '2dimageto3dmodel'...
# remote: Enumerating objects: 399, done.
# remote: Total 399 (delta 0), reused 0 (delta 0), pack-reused 399
# Receiving objects: 100% (399/399), 182.07 MiB | 22.34 MiB/s, done.
# Resolving deltas: 100% (127/127), done.
# Checking out files: 100% (217/217), done.

# %%
# %cd /content/2dimageto3dmodel
# !git clone https://github.com/NVIDIAGameWorks/kaolin.git
# Out:
# [Errno 2] No such file or directory: '/content/2dimageto3dmodel'
# /content/drive/MyDrive/2DimageTo3dModel
# Cloning into 'kaolin'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 1931 (delta 26), reused 26 (delta 9), pack-reused 1846
# Receiving objects: 100% (1931/1931), 53.82 MiB | 22.05 MiB/s, done.
# Resolving deltas: 100% (948/948), done.
# Checking out files: 100% (190/190), done.

# %%
# %cd kaolin
! python setup.py build_ext --inplace   # optional, allows importing kaolin from the kaolin root directory
! python setup.py install
# Out:
# /content/drive/My Drive/2DimageTo3dModel/kaolin
# setup.py:44: UserWarning: Kaolin is compatible with cython == 0.29.20, but found version 0.29.22 instead. This will try to install torch in the right version. If the installation fails we recommend to first install it.
#   warnings.warn('Kaolin is compatible with cython == 0.29.20, '
#      |████████████████████████████████| 2.0MB 18.2MB/s
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:727: UserWarning: Module Cython was already imported from /usr/local/lib/python3.7/dist-packages/Cython/__init__.py, but /content/drive/My Drive/2DimageTo3dModel/kaolin/.eggs/Cython-0.29.20-py3.7-linux-x86_64.egg is being added to sys.path
#   pkg_resources.working_set.add(dist, replace=True)
# ...
# Compiling kaolin/csrc/cpu/ops/conversions/mise.pyx because it changed.
# [1/1] Cythonizing kaolin/csrc/cpu/ops/conversions/mise.pyx
# ...

# %%
! pip install --no-dependencies nuscenes-devkit opencv-python-headless scikit-learn joblib pyquaternion cachetools
! pip install packaging
# Out:
# ...
#      |████████████████████████████████| 286kB 18.4MB/s
# ...
#      |████████████████████████████████| 37.6MB 76kB/s
# ...

# %%
# %cd /content/drive/MyDrive/2DimageTo3dModel/2dimageto3dmodel/code
# Out:
# /content/drive/MyDrive/2DimageTo3dModel/2dimageto3dmodel/code

# %%
# !python main.py --dataset cub --batch_size 16 --weights pretrained_weights_cub --save_results
# Out:
# CUB 200-2011 dataset with 5964 images is successfully loaded.
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Traceback (most recent call last):
#   File "main.py", line 149, in <module>
#     from rendering.renderer import Renderer
#   File "/content/drive/My Drive/2DimageTo3dModel/2dimageto3dmodel/code/rendering/renderer.py", line 1, in <module>
#     from kaolin.graphics.dib_renderer.rasterizer import linear_rasterizer
# ModuleNotFoundError: No module named 'kaolin.graphics'
