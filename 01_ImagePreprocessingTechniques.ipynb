# %% [markdown]
# <a href="https://colab.research.google.com/github/YonDraco/learn-deep-learning/blob/main/01_ImagePreprocessingTechniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import skimage
from skimage import data

import numpy as np

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
bird = mpimg.imread("/content/gdrive/MyDrive/Colab Notebooks/ImageClassificationwithPyTorch/datasets/images/bird.jpeg")

# %%
plt.title("Original Image")
plt.imshow(bird)

# %%
bird.shape
# Out:
# (750, 500, 3)

# %%
bird[200: 250, 200: 250]
# Out:
# array([[[157,   9,   9],
#         [178,  25,  28],
#         [186,  30,  34],
#         ...,
#         [ 58,  90, 167],
#         [ 45,  84, 151],
#         [ 57, 102, 157]],
#
#        [[148,   6,   5],
#         [164,  18,  21],
#         [170,  21,  27],
#         ...,
#         [ 68,  91, 171],
#         [ 51,  84, 153],
#         [ 61, 101, 160]],
#
#        [[139,   3,   5],
#         [150,   9,  15],
#         [152,   9,  15],
#         ...,
#         [ 71,  88, 170],
#         [ 56,  85, 155],
#         [ 63, 103, 165]],
#
#        ...,
#
#        [[197,  26,  16],
#         [209,  28,  21],
#         [215,  26,  24],
#         ...,
#         [ 35,  53, 125],
#         [ 49,  42, 119],
#         [ 41,  48, 116]],
#
#        [[199,  27,  17],
#         [213,  30,  26],
#         [220,  32,  30],
#         ...,
#         [ 31,  49, 121],
#         [ 45,  38, 115],
#         [ 34,  43, 108]],
#
#        [[199,  27,  17],
#         [210,  28,  24],
#         [215,  31,  29],
#         ...,
#         [ 33,  52, 121],
#         [ 41,  41, 113],
#         [ 31,  45, 108]]], dtype=uint8)

# %%
bird_reshape = bird.reshape(bird.shape[0] ,-1)
bird_reshape.shape
# Out:
# (750, 1500)

# %%
plt.figure (figsize = (6, 6))
plt.title("Reshaped Image")
plt.imshow(bird_reshape)

# %%
from skimage import transform

# %% [markdown]
# Tăng chiều dài, rộng theo tỷ lệ ảnh gốc vd (y,x) (500,400)

# %%
bird_resized = skimage.transform.resize(bird, (500, 500))
bird_resized.shape
# Out:
# (500, 500, 3)

# %%
plt.figure (figsize = (6,6))
plt.title("Resized Image")
plt.imshow(bird_resized)

# %%
aspect_ratio_original = bird.shape[1] / float(bird.shape[0])
aspect_ratio_resized = bird_resized.shape[1] / float(bird_resized.shape[0])

print("Original aspect ratio: ", aspect_ratio_original)
print("Resized aspect ratio: ", aspect_ratio_resized)
# Out:
# Original aspect ratio:  0.6666666666666666
# Resized aspect ratio:  1.0

# %% [markdown]
# ***Thay đổi tỷ lệ duy trì khung hình gốc***

# %%
from skimage.transform import rescale

# %%
bird_rescaled = skimage.transform.rescale(bird_resized, (1.0))

bird_rescaled.shape
# Out:
# (500, 500, 3)

# %%
plt.figure(figsize=(6,6)) 
plt.title("Rescaled Image")
plt.imshow(bird_rescaled)

# %%
aspect_ratio_rescaled = bird_rescaled.shape[1] / float(bird_rescaled.shape[0])

print("Rescaled aspect ratio: ", aspect_ratio_rescaled)
# Out:
# Rescaled aspect ratio:  1.0

# %% [markdown]
# ***Chuyển màu RGB sang BGR***

# %%
bird_BGR = bird[:, :, (2, 1, 0)]

plt.figure (figsize = (6, 6))
plt.title("BGR Image")
plt.imshow(bird_BGR)

# %%
bird_BGR.shape
# Out:
# (750, 500, 3)

# %%
bird_gray = skimage.color.rgb2gray(bird)

plt.figure (figsize = (6,6))
plt.title("Gray Image")
plt.imshow(bird_gray, cmap = 'gray')

# %%
bird_gray.shape
# Out:
# (750, 500)

# %% [markdown]
# ***Cắt ảnh***

# %%
import skimage.io

# %%
giraffes = skimage.img_as_float(skimage.io.imread('/content/drive/MyDrive/Colab Notebooks/ImageClassificationwithPyTorch/datasets/images/giraffes.jpg')).astype(np.float32)

plt.figure (figsize = (6, 6))
plt.title("Original Image")
plt.imshow(giraffes)

# %%
giraffes.shape
# Out:
# (378, 500, 3)

# %%
def crop(image, cropx, cropy):
    
    y, x, c = image.shape
    
    startx = x//2 - (cropx // 8)
    starty = y//3 - (cropy // 4) 
    
    stopx = startx + cropx
    stopy = starty + 2*cropy
    
    return image[starty:stopy, startx:stopx]

# %%
giraffes_cropped = crop (giraffes, 256, 256)

plt.figure (figsize = (6,6))
plt.title("Cropped Image")
plt.imshow(giraffes_cropped)

# %% [markdown]
#  ***Giảm chất lượng ảnh***

# %%
from skimage.util import random_noise

# %%
sigma = 0.155
noisy_giraffes = random_noise(giraffes, var=sigma**2)

plt.figure (figsize = (6, 6))
plt.title("Image with added noise")
plt.imshow(noisy_giraffes)

# %% [markdown]
# ***Ước tính độ lệch chuẩn nhiễu trung bình trên các kênh màu.***

# %%
from skimage.restoration import denoise_tv_chambolle, denoise_bilateral, denoise_wavelet, estimate_sigma

# %%
sigma_est = estimate_sigma(noisy_giraffes, 
                           multichannel=True, 
                           average_sigmas=True)
sigma_est
# Out:
# 0.14773379342346663

# %%
plt.imshow(denoise_tv_chambolle(noisy_giraffes, 
                                weight=0.1, 
                                multichannel=True))

# %%
plt.imshow(denoise_bilateral(noisy_giraffes, 
                             sigma_color=0.05, 
                             sigma_spatial=15,
                             multichannel=True))

# %%
plt.imshow(denoise_wavelet(noisy_giraffes, multichannel=True))

# %% [markdown]
# ***Hiệu ứng ảnh***

# %%
monkeys = skimage.img_as_float(skimage.io.imread('/content/drive/MyDrive/Colab Notebooks/ImageClassificationwithPyTorch/datasets/images/monkeys.jpeg')).astype(np.float32)

plt.figure (figsize = (6, 6))
plt.title("Original Image")
plt.imshow(monkeys)

# %% [markdown]
# ***Lật ảnh***

# %%
monkeys_flip = np.fliplr(monkeys)

plt.figure (figsize = (6, 6))
plt.title("Horizontal Flip")
plt.imshow(monkeys_flip)

# %%
monkeys_flip = np.flipud(monkeys)

plt.figure (figsize = (6, 6))
plt.title("Vertical Flip")
plt.imshow(monkeys_flip)

# %%
mirror = skimage.img_as_float(skimage.io.imread('/content/gdrive/MyDrive/Colab Notebooks/ImageClassificationwithPyTorch/datasets/images/book-mirrored.jpg')).astype(np.float32)

plt.figure (figsize = (6,6))
plt.title("Original Image")
plt.imshow(mirror)

# %%
mirror_flip = np.fliplr(mirror)

plt.figure (figsize = (6, 6))
plt.title("Horizontal Flip")
plt.imshow(mirror_flip)

# %% [markdown]
# ***Xoay ảnh***

# %%
monkeys_rotate = np.rot90(monkeys, 3)

plt.figure (figsize = (6, 6))
plt.title("Rotated Image")
plt.imshow(monkeys_rotate)

# %%
import random
from scipy import ndarray

def random_rotation(image_array: ndarray):

    random_degree = random.uniform(-25, 25)
    return skimage.transform.rotate(image_array, random_degree)

# %%
monkeys_angle= random_rotation (monkeys)

plt.figure (figsize = (6,6))
plt.title("Rotated Image")
plt.imshow(monkeys_angle)

# %% [markdown]
# ***Xoáy ảnh***

# %%
from skimage.transform import swirl
monkeys_swirl = swirl(monkeys, strength=10, radius = 300)

plt.figure (figsize = (6, 6))
plt.title("Swirled Image")
plt.imshow(monkeys_swirl)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from skimage.transform import swirl
test_swirl = swirl(test, strength=10, radius = 1000)

plt.figure (figsize = (6, 6))
plt.title("Swirled Image")
plt.imshow(test_swirl)
